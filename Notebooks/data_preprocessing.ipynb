# %% [markdown]
# **DATA PREPROCESSING**

# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np

# %%
# Importing the dataset
isco_08_df = pd.read_csv("ISCO-08-Data.csv")

# Number of rows and columns
isco_08_df.shape
# Out:
# (619, 8)

# %%
# Replacing spaces with underscores in column names
isco_08_df.columns = isco_08_df.columns.str.replace(' ', '_')
isco_08_df.columns
# Out:
# Index(['Level', 'ISCO_08_Code', 'Title_EN', 'Definition', 'Tasks_include',
#        'Included_occupations', 'Excluded_occupations', 'Notes'],
#       dtype='object')

# %%
# Filter rows where the column "ISCO_08_Code" contains exactly 4 digits
isco_08_df = isco_08_df[isco_08_df['ISCO_08_Code'].astype(str).str.match(r'^\d{4}$')]
isco_08_df.head()
# Out:
#    Level  ISCO_08_Code                                           Title_EN  \
# 3      4          1111                                        Legislators
# 4      4          1112                        Senior Government Officials
# 5      4          1113           Traditional Chiefs and Heads of Villages
# 6      4          1114  Senior Officials of Special-interest Organizat...
# 8      4          1120            Managing Directors and Chief Executives
#
#                                           Definition  \
# 3  Legislators determine, formulate, and direct p...
# 4  Senior government officials advise governments...
# 5  Traditional chiefs and heads of villages perfo...
# 6  Senior officials of special-interest organizat...
# 8  Managing directors and chief executives formul...
#
#                                        Tasks_include  \
# 3  Tasks include -\n(a)  presiding over or partic...
# 4  Tasks include -\n(a)  advising national, state...
# 5  Tasks include -\n(a)  allocating the use of co...
# 6  Tasks include -\n(a)  determining and formulat...
# 8  Tasks include -\n(a)  planning, directing and ...
#
#                                 Included_occupations Excluded_occupations  \
# 3  Examples of the occupations classified here:\n...                  NaN
# 4  Examples of the occupations classified here:\n...                  NaN
# 5  Examples of the occupations classified here:\n...                  NaN
# 6  Examples of the occupations classified here:\n...                  NaN
# 8  Examples of the occupations classified here:\n...                  NaN
#
#                                                Notes
# 3                                                NaN
# 4  Chief executives of Government-owned enterpris...
# 5                                                NaN
# 6                                                NaN
# 8  Regional managers and other senior managers wh...

# %%
# Combining all columns into "detailed_explanation"
isco_08_df["detailed_explanation"] = isco_08_df.apply(
    lambda row: "\n".join(
        [
            f"{col}:\n{row[col]}"
            for col in isco_08_df.columns if col != "detailed_explanation"
        ]
    ),
    axis=1
)

isco_08_df.head()
# Out:
#    Level  ISCO_08_Code                                           Title_EN  \
# 3      4          1111                                        Legislators
# 4      4          1112                        Senior Government Officials
# 5      4          1113           Traditional Chiefs and Heads of Villages
# 6      4          1114  Senior Officials of Special-interest Organizat...
# 8      4          1120            Managing Directors and Chief Executives
#
#                                           Definition  \
# 3  Legislators determine, formulate, and direct p...
# 4  Senior government officials advise governments...
# 5  Traditional chiefs and heads of villages perfo...
# 6  Senior officials of special-interest organizat...
# 8  Managing directors and chief executives formul...
#
#                                        Tasks_include  \
# 3  Tasks include -\n(a)  presiding over or partic...
# 4  Tasks include -\n(a)  advising national, state...
# 5  Tasks include -\n(a)  allocating the use of co...
# 6  Tasks include -\n(a)  determining and formulat...
# 8  Tasks include -\n(a)  planning, directing and ...
#
#                                 Included_occupations Excluded_occupations  \
# 3  Examples of the occupations classified here:\n...                  NaN
# 4  Examples of the occupations classified here:\n...                  NaN
# 5  Examples of the occupations classified here:\n...                  NaN
# 6  Examples of the occupations classified here:\n...                  NaN
# 8  Examples of the occupations classified here:\n...                  NaN
#
#                                                Notes  \
# 3                                                NaN
# 4  Chief executives of Government-owned enterpris...
# 5                                                NaN
# 6                                                NaN
# 8  Regional managers and other senior managers wh...
#
#                                 detailed_explanation
# 3  Level:\n4\nISCO_08_Code:\n1111\nTitle_EN:\nLeg...
# 4  Level:\n4\nISCO_08_Code:\n1112\nTitle_EN:\nSen...
# 5  Level:\n4\nISCO_08_Code:\n1113\nTitle_EN:\nTra...
# 6  Level:\n4\nISCO_08_Code:\n1114\nTitle_EN:\nSen...
# 8  Level:\n4\nISCO_08_Code:\n1120\nTitle_EN:\nMan...

# %%
# Saving the preprocessed data
isco_08_df.to_csv("preprocessed_isco_08_data.csv", index=False)
