# %%
# Importing the necessary libraries
import openai
import pandas as pd
import numpy as np
from pathlib import Path
from dotenv import load_dotenv
import os

# %%
from embedding_functions import get_embedding

# %%
# Set up directories
DATA_DIR = Path.cwd().parent.joinpath("data")
EMBEDDINGS_DIR = Path.cwd().parent.joinpath("data/embeddings")
OUTPUTS_DIR = Path.cwd().parent.joinpath("data/outputs")
PROCESSED_DIR = Path.cwd().parent.joinpath("data/processed")
TEST_DIR = Path.cwd().parent.joinpath("data/test_data")

# %%
client = openai

# %%
# Load environment variables from the .env file
load_dotenv()

# Access environment variables as if they came from the actual environment
api_key = os.getenv("API_KEY")

# %%
# Accessing the openai api_key
# REMOVE?
client.api_key = "API_Key"

# %%
# Importing the preprocessed data
preprocessed_isco_08_data = pd.read_csv(PROCESSED_DIR.joinpath("preprocessed_isco_08_data.csv"))

# %%
# Creating the Embeddings in the dataset
preprocessed_isco_08_data['embeddings'] = preprocessed_isco_08_data["detailed_explanation"].apply(get_embedding)

# saving the embedded data
preprocessed_isco_08_data.to_csv(EMBEDDINGS_DIR / "isco_08_df_with_embeddings.csv", index = False)
preprocessed_isco_08_data.to_pickle(EMBEDDINGS_DIR / "isco_08_df_with_embeddings.pkl")

# %%
# Importing the embedded data
isco_08_df_with_embeddings = pd.read_pickle(EMBEDDINGS_DIR.joinpath("isco_08_df_with_embeddings.pkl"))

# retrieving the first few rows of embeddings column
isco_08_df_with_embeddings['embeddings'].head()
# Out:
# 3    [0.0013290219940245152, 0.007148989010602236, ...
# 4    [0.007645719218999147, -0.007002497091889381, ...
# 5    [-0.007697697263211012, 0.005955907050520182, ...
# 6    [-0.014344722963869572, -0.023523719981312752,...
# 8    [-0.017747338861227036, -0.008417422883212566,...
# Name: embeddings, dtype: object
